# %%
from Electron_SDD_Generator import Electron_SDD_Generator
from Electron_SDD_Generator import Electron_SDD_Generator_DoseRate
import time

# %%
#Input energy in keV
InputEnergy = 500
#Input dose in Gy
InputDose = 1.16
#Author name in string
Author = "Anthony Lim"
#TimeStamp in ns, inverse of dose rate
TimeStamp = 7.03E10
#HalfLife in s
HalfLife = 6.9 * 3600 * 24

# %%
#in case multiple generation of SDD files
Iter_Numb = 150
recurrsionN = 0
LookTime = []
while recurrsionN < Iter_Numb:
    t = time.time()
    Electron_SDD_Generator_DoseRate(InputEnergy, InputDose, Author, TimeStamp, HalfLife)
    recurrsionN = recurrsionN + 1
    elasped = time.time()-t
    LookTime.append(elasped)
print(LookTime)
# Out:
# [1.297861099243164, 1.2782599925994873, 1.2931530475616455, 1.2894952297210693, 1.2872259616851807, 1.3172249794006348, 1.296548843383789, 1.312514066696167, 1.30989408493042, 1.3372149467468262, 1.3730411529541016, 1.3101699352264404, 1.3083043098449707, 1.2639498710632324, 1.2698149681091309, 1.2647638320922852, 1.2543339729309082, 1.2723231315612793, 1.2614798545837402, 1.2916269302368164, 1.2659521102905273, 1.2859079837799072, 1.2868030071258545, 1.279592752456665, 1.319770097732544, 1.3158369064331055, 1.299489974975586, 1.2918589115142822, 1.2844901084899902, 1.2948668003082275, 1.3098578453063965, 1.280641794204712, 1.2992382049560547, 1.2725551128387451, 1.2924401760101318, 1.2770328521728516, 1.2714500427246094, 1.2949728965759277, 1.2693681716918945, 1.263261079788208, 1.2831051349639893, 1.2930500507354736, 1.2739019393920898, 1.274878978729248, 1.2944920063018799, 1.3312900066375732, 1.3170719146728516, 1.3260490894317627, 1.3072571754455566, 1.3169310092926025, 1.305124
# ...

# %%
Electron_SDD_Generator_DoseRate(InputEnergy, InputDose, Author, TimeStamp, HalfLife)

# %%
Electron_SDD_Generator(InputEnergy, InputDose, Author)
