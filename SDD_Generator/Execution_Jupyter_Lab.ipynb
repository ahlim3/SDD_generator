# %%
from Electron_SDD_Generator import Electron_SDD_Generator

# %%
#Input energy in keV
InputEnergy = 1000
#Input dose in Gy
InputDose = 10
#Author name in string
Author = "Anthony Lim"

# %%
Electron_SDD_Generator(InputEnergy, InputDose, Author)
# Out:
# New 1000keV Folder

# %%
#in case multiple generation of SDD files
Iter_Numb = 10
recurrsionN = 0
while recurrsionN < 10:
    Electron_SDD_Generator(InputEnergy, InputDose, Author)
    recurrsionN = recurrsionN + 1
